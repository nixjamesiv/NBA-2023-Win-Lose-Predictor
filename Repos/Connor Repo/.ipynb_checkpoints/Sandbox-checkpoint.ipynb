# %%
import pickle
import pandas as pd
import requests

with open('../../Data/year_team.pickle', 'rb') as handle:
    year_team = pickle.load(handle)
with open('../../Data/year_position.pickle', 'rb') as handle:
    year_position = pickle.load(handle)
import warnings
# Out:
# C:\Users\AsuS\anaconda3\envs\learn-env\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# ! ls ../../Data/
win_loss_df = pd.read_csv("../../Data/win_loss_df_seasonal.csv")

# %%
win_loss_df
# Out:
#       team1-1-power-forward team1-1-point-guard team1-1-shooting-guard  \
# 0                      Null                Null                   Null
# 1                      Null                Null                   Null
# 2                      Null                Null                   Null
# 3                      Null                Null                   Null
# 4                      Null                Null                   Null
# ...                     ...                 ...                    ...
# 52665                  Null                Null                   Null
# 52666                  Null                Null                   Null
# 52667                  Null                Null                   Null
# 52668                  Null                Null                   Null
# 52669                  Null                Null                   Null
#
#       team1-1-small-forward team1-1-center team1-1-power-forward-exp  \
# 0                      Null           Null                      Null
# 1                      Null           Null                      Null
# 2                      Null           Null                      Null
# 3                      Null           Null                      Null
# 4                      Null           Null                      Null
# ...                     ...            ...                       ...
# 52665                  Null           Null                      Null
# 52666                  Null           Null                      Null
# 52667                  Null           Null                      Null
# 52668                  Null           Null                      Null
# 52669                  Null           Null                      Null
#
#       team1-1-point-guard-exp team1-1-shooting-guard-exp  \
# 0                        Null                       Null
# 1                        Null                       Null
# 2                        Null                       Null
# 3                        Null                       Null
# 4                        Null                       Null
# ...                       ...                        ...
# 52665                    Null                       Null
# 52666                    Null                       Null
# 52667                    Null                       Null
# 52668                    Null                       Null
# 52669                    Null                       Null
#
#       team1-1-small-forward-exp team1-1-center-exp  ... team2-2-center  \
# 0                          Null               Null  ...           Null
# 1                          Null               Null  ...           Null
# 2                          Null               Null  ...           Null
# 3                          Null               Null  ...           Null
# 4                          Null               Null  ...           Null
# ...                         ...                ...  ...            ...
# 52665                      Null               Null  ...           Null
# 52666                      Null               Null  ...           Null
# 52667                      Null               Null  ...           Null
# 52668                      Null               Null  ...           Null
# 52669                      Null               Null  ...           Null
#
#       team2-2-power-forward-exp team2-2-point-guard-exp  \
# 0                          Null                    Null
# 1                          Null                    Null
# 2                          Null                    Null
# 3                          Null                    Null
# 4                          Null                    Null
# ...                         ...                     ...
# 52665                      Null                    Null
# 52666                      Null                    Null
# 52667                      Null                    Null
# 52668                      Null                    Null
# 52669                      Null                    Null
#
#       team2-2-shooting-guard-exp team2-2-small-forward-exp team2-2-center-exp  \
# 0                           Null                      Null               Null
# 1                           Null                      Null               Null
# 2                           Null                      Null               Null
# 3                           Null                      Null               Null
# 4                           Null                      Null               Null
# ...                          ...                       ...                ...
# 52665                       Null                      Null               Null
# 52666                       Null                      Null               Null
# 52667                       Null                      Null               Null
# 52668                       Null                      Null               Null
# 52669                       Null                      Null               Null
#
#       team2 team1 game_date  pts
# 0       WAS   TOR      2001   98
# 1       TOR   WAS      2001   92
# 2       GSW   VAN      2001   95
# 3       VAN   GSW      2001   81
# 4       CHH   BOS      2001   92
# ...     ...   ...       ...  ...
# 52665   IND   CHA      2021  123
# 52666   MIL   BKN      2021  104
# 52667   BKN   MIL      2021  127
# 52668   GSW   LAL      2021  114
# 52669   LAL   GSW      2021  121
#
# [52670 rows x 44 columns]

# %%
warnings.filterwarnings(action="ignore")

# %%
positions = [
    "power-forward",
    "point-guard",
    "shooting-guard",
    "small-forward",
    "center"
]
years = [str(x) for x in range(2001,2023)]
teams = [
    "ATL",
    "BOS",
    "WAS",
    "UTA",
    "TOR",
    "SAS",
    "SAC",
    "POR",
    "PHO",
    "PHI",
    "ORL",
    "OKC",
    "NYK",
    "NOH",
    "MIN",
    "MIL",
    "MIA",
    "MEM",
    "LAL",
    "LAC",
    "IND",
    "HOU",
    "GSW",
    "DET",
    "DEN",
    "DAL",
    "CLE",
    "CHI",
    "CHA",
    "NJN"
]
col_name = [
    "team1-1-power-forward",
    "team1-1-point-guard",
    "team1-1-shooting-guard",
    "team1-1-small-forward",
    "team1-1-center",

    "team1-1-power-forward-exp",
    "team1-1-point-guard-exp",
    "team1-1-shooting-guard-exp",
    "team1-1-small-forward-exp",
    "team1-1-center-exp",

    "team1-2-power-forward",
    "team1-2-point-guard",
    "team1-2-shooting-guard",
    "team1-2-small-forward",
    "team1-2-center",

    "team1-2-power-forward-exp",
    "team1-2-point-guard-exp",
    "team1-2-shooting-guard-exp",
    "team1-2-small-forward-exp",
    "team1-2-center-exp",

    "team2-1-power-forward",
    "team2-1-point-guard",
    "team2-1-shooting-guard",
    "team2-1-small-forward",
    "team2-1-center",

    "team2-1-power-forward-exp",
    "team2-1-point-guard-exp",
    "team2-1-shooting-guard-exp",
    "team2-1-small-forward-exp",
    "team2-1-center-exp",

    "team2-2-power-forward",
    "team2-2-point-guard",
    "team2-2-shooting-guard",
    "team2-2-small-forward",
    "team2-2-center",

    "team2-2-power-forward-exp",
    "team2-2-point-guard-exp",
    "team2-2-shooting-guard-exp",
    "team2-2-small-forward-exp",
    "team2-2-center-exp"
]

# %%
# win_loss_df = pd.read_excel("../../Data/NBA Win-Loss.xlsx")
# win_loss_df = win_loss_df.drop(columns=['win_lose', 'min', 'fgm', 'fga', 'fg_perc', '3pm', '3pa', '3p_perc', 'ftm', 'fta', 'ft_perc', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'tov', 'pg', 'plus_minus'])
# for col in col_name:
#     win_loss_df[col] = "Null"
# for x in range(0,len(win_loss_df["match_up"])):
#     win_loss_df["match_up"][x] = win_loss_df["match_up"].str.split(" ")[x][-1]
# for x in range(0,len(win_loss_df["game_date"])):
#     win_loss_df["game_date"][x] = win_loss_df["game_date"].astype(str).str.split("-")[x][0]
# win_loss_df["team2"] = win_loss_df["match_up"]
# win_loss_df = win_loss_df.drop(columns=["match_up"])
# win_loss_df["team1"] = win_loss_df["team"]
# win_loss_df = win_loss_df.drop(columns=["team"])

# %%
# win_loss_df[win_loss_df["game_date"]=="2019"]

# %%
# win_loss_df.to_excel("../../Data/win_loss_df.xlsx")

# %%
# win_loss_df

# %%
# win_loss_df[win_loss_df["game_date"] == "2019"]

# %%
# teams

# %%
# win_loss_df.info()

# %%
# year_team[(year,"CHA")]

# %%
# win_loss_df[win_loss_df["team2-1-point-guard"] == "Null"]["team2"].unique()

# %%
# win_loss_df[win_loss_df["team1-1-point-guard"] == "Null"]["team1"].unique()

# %%
# Testing Code

# %%
# # Working Code
# class PositionRanking:
#     def __init__(self):
#         self

# %%
def positionRankDF(year_team_dict, year, team, position):
    rank_list = []
    exp_list = []
    #check each row in year_team_dict if position is position
    for row in year_team_dict[(year,team)].index:
        if position == year_team_dict[(year,team)]["Pos"][row]:
            rank_list.append(year_team_dict[(year,team)]["rank"][row])
            exp_list.append(year_team_dict[(year,team)]["Exp"][row])
    #creates rank pd
    rank_exp_pd = pd.DataFrame({"rank":rank_list,"exp":exp_list})
    #ranks rank pd
    rank_exp_pd.sort_values(by="rank")
    return rank_exp_pd

# %%
def positionRankDFFilter(year_team_dict, year, team, position):
    #rank lists/exp lists
    if team == "PHX":
        team1 = "PHO"
        return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
    elif team == "BKN":
        team1 = "BRK"
        return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
#     elif team == "CHA":
#         team1 = "CHO"
#         return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
    else:
        return positionRankDF(year_team_dict, year, team, position)

# %%
def positionRanker(year, team, position, rank_exp_pd, year_team_dict):
    for num in range(1,3):
        for pd_row in win_loss_df.index:
            if team == win_loss_df["team"+str(num)][pd_row]:
                if year == win_loss_df["game_date"][pd_row]:
                    print(year_team_dict[(year,team)], position)
                    try:
                        # trys main position to give rank and exp
                        win_loss_df["team"+str(num)+"-1-"+position][pd_row] = rank_exp_pd["rank"][0]
                        win_loss_df["team"+str(num)+"-1-"+position+"-exp"][pd_row] = rank_exp_pd["exp"][0]
                    except:
                        for position1 in positions:
                            try:
                                #trys different positions to grab from if there are not 1 of main positions
                                rank_exp_pd1 = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position1)
                                win_loss_df["team"+str(num)+"-1-"+position][pd_row] = rank_exp_pd1["rank"][2]
                                win_loss_df["team"+str(num)+"-1-"+position+"-exp"][pd_row] = rank_exp_pd1["exp"][2]
                                print("1 Success",position1,position)
                                break
                            except:
                                print("1 Fail",position1,position)
                    try:
                        # trys main position to give rank and exp
                        win_loss_df["team"+str(num)+"-2-"+position][pd_row] = rank_exp_pd["rank"][1]
                        win_loss_df["team"+str(num)+"-2-"+position+"-exp"][pd_row] = rank_exp_pd["exp"][1]
                    except:
                        #trys different positions to grab from if there are not 2 of main positions
                        for position1 in positions:
                            try:
                                rank_exp_pd1 = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position1)
                                win_loss_df["team"+str(num)+"-2-"+position][pd_row] = rank_exp_pd1["rank"][2]
                                win_loss_df["team"+str(num)+"-2-"+position+"-exp"][pd_row] = rank_exp_pd1["exp"][2]
                                print("2 Success",position1,position)
                                break
                            except:
                                print("2 Fail",position1,position)

# %%
def fullPositionRanker(year_team_dict, year, team, position):
    rank_exp_pd = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position)
    if team == "PHO":
        team1 = "PHX"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    elif team == "BRK":
        team1 = "BKN"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    elif team == "CHO":
        team1 = "CHA"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    else:
        positionRanker(year=year, team=team, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)

# %%
# iterates through year and team to cycle through year_team data frames
for year in years:
    for team in teams:
        print("1")
        # iterates through position to grab different positions in year_team[(year,team)] data frame
        for position in positions:
#             print("2")
            # outer if, elif, else chain takes into acount team name change
            if team == "OKC" and year in [str(x) for x in range(2001,2009)]:
                team1 = "SEA"
                print("3")
                # cycles through year_team[(year,team1)] to fin players of certain positions to rank them
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            #Team name change NOH
            elif team == "NOH" and year not in ["2003", "2004", "2005", "2008", "2009", "2010", "2011", "2012", "2013"]:
                try:
                    if year in ["2006", "2007"]:
                        team1 = "NOK"
                        print("4.1")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                    else:
                        team1 = "NOP"
                        print("4.2")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass
            #Team name change MEM
            elif team == "MEM" and year == "2001":
                team1 = "VAN"
                print("5")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            #Team name change CHA
            elif team == "CHA" and (year in ["2001", "2002", "2003", "2004"] or year in [str(x) for x in range(2015,2023)]):
                try:
                    if year in [str(x) for x in range(2015,2023)]:
                        team1 = "CHO"
                        print("6.1")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass 
                try:
                    if year in ["2001", "2002"]:
                        team1 = "CHH"
                        print("6.2")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass
            #Team name change NJN
            elif team == "NJN" and year in [str(x) for x in range(2013,2023)]:
                team1 = "BRK"
                print("7")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            else:
                print("8")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team, position=position)
            print(year,team)
# Out:
# 1
# 8
# 2001 ATL
# 8
# 2001 ATL
# 8
# 2001 ATL
# 8
# 2001 ATL
# 8
# 2001 ATL
# 1
# 8
# 2001 BOS
# 8
# 2001 BOS
# 8
# 2001 BOS
# 8
# 2001 BOS
# 8
# 2001 BOS
# 1
# 8
# 2001 WAS
# 8
# 2001 WAS
# 8
# 2001 WAS
# 8
# 2001 WAS
# 8
# 2001 WAS
# 1
# 8
# 2001 UTA
# 8
# 2001 UTA
# 8
# 2001 UTA
# 8
# 2001 UTA
# 8
# 2001 UTA
# 1
# 8
# 2001 TOR
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-fa481daa74b9> in <module>
#      53             else:
#      54                 print("8")
# ---> 55                 fullPositionRanker(year_team_dict=year_team, year=year, team=team, position=position)
#      56             print(year,team)
#
# <ipython-input-19-23c65393008d> in fullPositionRanker(year_team_dict, year, team, position)
#      11         positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
#      12     else:
# ---> 13         positionRanker(year=year, team=team, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
#      14
#
# <ipython-input-18-cc53734f7df8> in positionRanker(year, team, position, rank_exp_pd, year_team_dict)
#       2     for num in range(1,3):
#       3         for pd_row in win_loss_df.index:
# ----> 4             if team == win_loss_df["team"+str(num)][pd_row]:
#       5                 if year == win_loss_df["game_date"][pd_row]:
#       6                     print(year_team_dict[(year,team)], position)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988         # Similar to Index.get_value, but we do not fall back to positional
#     989         loc = self.index.get_loc(label)
# --> 990         return self.index._get_values_for_loc(self, loc, label)
#     991
#     992     def __setitem__(self, key, value):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in _get_values_for_loc(self, series, loc, key)
#    4631         """
#    4632         if is_integer(loc):
# -> 4633             return series._values[loc]
#    4634
#    4635         return series.iloc[loc]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in _values(self)
#     570
#     571         """
# --> 572         return self._mgr.internal_values()
#     573
#     574     @Appender(base.IndexOpsMixin.array.__doc__)  # type: ignore
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\managers.py in internal_values(self)
#    1613     def internal_values(self):
#    1614         """The array that Series._values returns"""
# -> 1615         return self._block.internal_values()
#    1616
#    1617     @property
#
# KeyboardInterrupt:

# %%
# Out:
# Index(['team1-1-power-forward', 'team1-1-point-guard',
#        'team1-1-shooting-guard', 'team1-1-small-forward', 'team1-1-center',
#        'team1-1-power-forward-exp', 'team1-1-point-guard-exp',
#        'team1-1-shooting-guard-exp', 'team1-1-small-forward-exp',
#        'team1-1-center-exp', 'team1-2-power-forward', 'team1-2-point-guard',
#        'team1-2-shooting-guard', 'team1-2-small-forward', 'team1-2-center',
#        'team1-2-power-forward-exp', 'team1-2-point-guard-exp',
#        'team1-2-shooting-guard-exp', 'team1-2-small-forward-exp',
#        'team1-2-center-exp', 'team2-1-power-forward', 'team2-1-point-guard',
#        'team2-1-shooting-guard', 'team2-1-small-forward', 'team2-1-center',
#        'team2-1-power-forward-exp', 'team2-1-point-guard-exp',
#        'team2-1-shooting-guard-exp', 'team2-1-small-forward-exp',
#        'team2-1-center-exp', 'team2-2-power-forward', 'team2-2-point-guard',
#        'team2-2-shooting-guard', 'team2-2-small-forward', 'team2-2-center',
#        'team2-2-power-forward-exp', 'team2-2-point-guard-exp',
#        'team2-2-shooting-guard-exp', 'team2-2-small-forward-exp',
#        'team2-2-center-exp', 'team2', 'team1', 'game_date', 'pts'],
#       dtype='object')

# %%
! ls ../../Data
# Out:
# NBA Win-Loss.xlsx
# win_loss_df.xlsx
# year_position.pickle
# year_team.pickle

# %%
win_loss_df.to_csv("../../Data/win_loss_seasonal_completed_df.csv", index=False)

# %%
# for x in range(1,3):
#     for position in positions:
#         print(x,position)
#         print(win_loss_df[win_loss_df["team2-"+str(x)+"-"+position] == "Null"]["team2"].unique())

# for x in range(1,3):
#     for position in positions:
#         print(x,position)
#         print(win_loss_df[win_loss_df["team1-"+str(x)+"-"+position] == "Null"]["team1"].unique())

# %%
# win_loss_df[(win_loss_df["team1-2-center"] == "Null")&(win_loss_df["team1"] == "NYK")]

# %%
# win_loss_df[(win_loss_df["team1"] == "CHO")]

# %%
# for year in years:
#     for team in teams:
#         try:
#             if len(year_team[(year,team)]) < 9:
#                 print(year,team)
#         except:
#             pass

# %%
# year_team[("2012","NYK")]

# %%
# win_loss_df[(win_loss_df["team1"] == "SAS") & (win_loss_df["team1-1-power-forward"] == "Null")]

# %%
# win_loss_df[win_loss_df["team2-1-point-guard"] == "Null"]
