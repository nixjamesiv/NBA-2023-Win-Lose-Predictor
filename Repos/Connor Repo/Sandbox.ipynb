# %%
import pickle
import pandas as pd
import requests

with open('../../Data/year_team.pickle', 'rb') as handle:
    year_team = pickle.load(handle)
with open('../../Data/year_position.pickle', 'rb') as handle:
    year_position = pickle.load(handle)
import warnings
# Out:
# C:\Users\AsuS\anaconda3\envs\learn-env\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# ! ls ../../Data/

# %%
warnings.filterwarnings(action="ignore")

# %%
positions = [
    "power-forward",
    "point-guard",
    "shooting-guard",
    "small-forward",
    "center"
]
years = [str(x) for x in range(2001,2023)]
teams = [
    "ATL",
    "BOS",
    "WAS",
    "UTA",
    "TOR",
    "SAS",
    "SAC",
    "POR",
    "PHO",
    "PHI",
    "ORL",
    "OKC",
    "NYK",
    "NOH",
    "MIN",
    "MIL",
    "MIA",
    "MEM",
    "LAL",
    "LAC",
    "IND",
    "HOU",
    "GSW",
    "DET",
    "DEN",
    "DAL",
    "CLE",
    "CHI",
    "CHA",
    "NJN"
]
col_name = [
    "team1-1-power-forward",
    "team1-1-point-guard",
    "team1-1-shooting-guard",
    "team1-1-small-forward",
    "team1-1-center",

    "team1-1-power-forward-exp",
    "team1-1-point-guard-exp",
    "team1-1-shooting-guard-exp",
    "team1-1-small-forward-exp",
    "team1-1-center-exp",

    "team1-2-power-forward",
    "team1-2-point-guard",
    "team1-2-shooting-guard",
    "team1-2-small-forward",
    "team1-2-center",

    "team1-2-power-forward-exp",
    "team1-2-point-guard-exp",
    "team1-2-shooting-guard-exp",
    "team1-2-small-forward-exp",
    "team1-2-center-exp",

    "team2-1-power-forward",
    "team2-1-point-guard",
    "team2-1-shooting-guard",
    "team2-1-small-forward",
    "team2-1-center",

    "team2-1-power-forward-exp",
    "team2-1-point-guard-exp",
    "team2-1-shooting-guard-exp",
    "team2-1-small-forward-exp",
    "team2-1-center-exp",

    "team2-2-power-forward",
    "team2-2-point-guard",
    "team2-2-shooting-guard",
    "team2-2-small-forward",
    "team2-2-center",

    "team2-2-power-forward-exp",
    "team2-2-point-guard-exp",
    "team2-2-shooting-guard-exp",
    "team2-2-small-forward-exp",
    "team2-2-center-exp"
]

# %%
win_loss_df = pd.read_excel("../../Data/NBA Win-Loss.xlsx")
win_loss_df = win_loss_df.drop(columns=['win_lose', 'min', 'fgm', 'fga', 'fg_perc', '3pm', '3pa', '3p_perc', 'ftm', 'fta', 'ft_perc', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'tov', 'pg', 'plus_minus'])
for col in col_name:
    win_loss_df[col] = "Null"
for x in range(0,len(win_loss_df["match_up"])):
    win_loss_df["match_up"][x] = win_loss_df["match_up"].str.split(" ")[x][-1]
for x in range(0,len(win_loss_df["game_date"])):
    win_loss_df["game_date"][x] = win_loss_df["game_date"].astype(str).str.split("-")[x][0]
win_loss_df["team2"] = win_loss_df["match_up"]
win_loss_df = win_loss_df.drop(columns=["match_up"])
win_loss_df["team1"] = win_loss_df["team"]
win_loss_df = win_loss_df.drop(columns=["team"])

# %%
# win_loss_df[win_loss_df["game_date"]=="2019"]

# %%
# win_loss_df.to_excel("../../Data/win_loss_df.xlsx")

# %%
# win_loss_df

# %%
# win_loss_df[win_loss_df["game_date"] == "2019"]

# %%
# teams

# %%
# win_loss_df.info()

# %%
# year_team[(year,"CHA")]

# %%
# win_loss_df[win_loss_df["team2-1-point-guard"] == "Null"]["team2"].unique()

# %%
# win_loss_df[win_loss_df["team1-1-point-guard"] == "Null"]["team1"].unique()

# %%
# Testing Code

# %%
# # Working Code
# class PositionRanking:
#     def __init__(self):
#         self

# %%
def positionRankDF(year_team_dict, year, team, position):
    rank_list = []
    exp_list = []
    #check each row in year_team_dict if position is position
    for row in year_team_dict[(year,team)].index:
        if position == year_team_dict[(year,team)]["Pos"][row]:
            rank_list.append(year_team_dict[(year,team)]["rank"][row])
            exp_list.append(year_team_dict[(year,team)]["Exp"][row])
    #creates rank pd
    rank_exp_pd = pd.DataFrame({"rank":rank_list,"exp":exp_list})
    #ranks rank pd
    rank_exp_pd.sort_values(by="rank")
    return rank_exp_pd

# %%
def positionRankDFFilter(year_team_dict, year, team, position):
    #rank lists/exp lists
    if team == "PHX":
        team1 = "PHO"
        return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
    elif team == "BKN":
        team1 = "BRK"
        return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
#     elif team == "CHA":
#         team1 = "CHO"
#         return positionRankDF(year_team_dict=year_team_dict, year=year, team=team1, position=position)
    else:
        return positionRankDF(year_team_dict, year, team, position)

# %%
def positionRanker(year, team, position, rank_exp_pd, year_team_dict):
    for num in range(1,3):
        for pd_row in win_loss_df.index:
            if team == win_loss_df["team"+str(num)][pd_row]:
                if year == win_loss_df["game_date"][pd_row]:
#                     print(year_team_dict[(year,team)], position)
                    try:
                        # trys main position to give rank and exp
                        win_loss_df["team"+str(num)+"-1-"+position][pd_row] = rank_exp_pd["rank"][0]
                        win_loss_df["team"+str(num)+"-1-"+position+"-exp"][pd_row] = rank_exp_pd["exp"][0]
                    except:
                        for position1 in positions:
                            try:
                                #trys different positions to grab from if there are not 1 of main positions
                                rank_exp_pd1 = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position1)
                                win_loss_df["team"+str(num)+"-1-"+position][pd_row] = rank_exp_pd1["rank"][2]
                                win_loss_df["team"+str(num)+"-1-"+position+"-exp"][pd_row] = rank_exp_pd1["exp"][2]
                                print("1 Success",position1,position)
                                break
                            except:
                                print("1 Fail",position1,position)
                    try:
                        # trys main position to give rank and exp
                        win_loss_df["team"+str(num)+"-2-"+position][pd_row] = rank_exp_pd["rank"][1]
                        win_loss_df["team"+str(num)+"-2-"+position+"-exp"][pd_row] = rank_exp_pd["exp"][1]
                    except:
                        #trys different positions to grab from if there are not 2 of main positions
                        for position1 in positions:
                            try:
                                rank_exp_pd1 = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position1)
                                win_loss_df["team"+str(num)+"-2-"+position][pd_row] = rank_exp_pd1["rank"][2]
                                win_loss_df["team"+str(num)+"-2-"+position+"-exp"][pd_row] = rank_exp_pd1["exp"][2]
                                print("2 Success",position1,position)
                                break
                            except:
                                print("2 Fail",position1,position)

# %%
def fullPositionRanker(year_team_dict, year, team, position):
    rank_exp_pd = positionRankDFFilter(year_team_dict=year_team_dict, year=year, team=team, position=position)
    if team == "PHO":
        team1 = "PHX"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    elif team == "BRK":
        team1 = "BKN"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    elif team == "CHO":
        team1 = "CHA"
        positionRanker(year=year, team=team1, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)
    else:
        positionRanker(year=year, team=team, position=position, rank_exp_pd=rank_exp_pd, year_team_dict=year_team)

# %%
# iterates through year and team to cycle through year_team data frames
for year in years:
    for team in teams:
        print("1")
        # iterates through position to grab different positions in year_team[(year,team)] data frame
        for position in positions:
            print("2")
            # outer if, elif, else chain takes into acount team name change
            if team == "OKC" and year in [str(x) for x in range(2001,2009)]:
                team1 = "SEA"
                print("3")
                # cycles through year_team[(year,team1)] to fin players of certain positions to rank them
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            #Team name change NOH
            elif team == "NOH" and year not in ["2003", "2004", "2005", "2008", "2009", "2010", "2011", "2012", "2013"]:
                try:
                    if year in ["2006", "2007"]:
                        team1 = "NOK"
                        print("4.1")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                    else:
                        team1 = "NOP"
                        print("4.2")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass
            #Team name change MEM
            elif team == "MEM" and year == "2001":
                team1 = "VAN"
                print("5")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            #Team name change CHA
            elif team == "CHA" and (year in ["2001", "2002", "2003", "2004"] or year in [str(x) for x in range(2015,2023)]):
                try:
                    if year in [str(x) for x in range(2015,2023)]:
                        team1 = "CHO"
                        print("6.1")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass 
                try:
                    if year in ["2001", "2002"]:
                        team1 = "CHH"
                        print("6.2")
                        fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
                except:
                    pass
            #Team name change NJN
            elif team == "NJN" and year in [str(x) for x in range(2013,2023)]:
                team1 = "BRK"
                print("7")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team1, position=position)
            else:
                print("8")
                fullPositionRanker(year_team_dict=year_team, year=year, team=team, position=position)
            print(year,team)
# Out:
# 1
# 2
# 8
# 2001 ATL
# 2
# 8
# 2001 ATL
# 2
# 8
# 2001 ATL
# 2
# 8
# 2001 ATL
# 2
# 8
# 2001 ATL
# 1
# 2
# 8
# 2001 BOS
# 2
# 8
# 2001 BOS
# 2
# 8
# 2001 BOS
# 2
# 8
# 2001 BOS
# 2
# 8
# 2001 BOS
# 1
# 2
# 8
# 2001 WAS
# 2
# 8
# 2001 WAS
# 2
# 8
# 2001 WAS
# 2
# 8
# 2001 WAS
# 2
# 8
# 2001 WAS
# 1
# 2
# 8
# 2001 UTA
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2001 UTA
# 2
# 8
# 2001 UTA
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 UTA
# 2
# 8
# 2001 UTA
# 1
# 2
# 8
# 2001 TOR
# 2
# 8
# 2001 TOR
# 2
# 8
# 2001 TOR
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 TOR
# 2
# 8
# 2001 TOR
# 1
# 2
# 8
# 2001 SAS
# 2
# 8
# 2001 SAS
# 2
# 8
# 2001 SAS
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 SAS
# 2
# 8
# 2001 SAS
# 1
# 2
# 8
# 2001 SAC
# 2
# 8
# 2001 SAC
# 2
# 8
# 2001 SAC
# 2
# 8
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 1 Fail power-forward small-forward
# 1 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2001 SAC
# 2
# 8
# 2001 SAC
# 1
# 2
# 8
# 2001 POR
# 2
# 8
# 2001 POR
# 2
# 8
# 2001 POR
# 2
# 8
# 2001 POR
# 2
# 8
# 2001 POR
# 1
# 2
# 8
# 2001 PHO
# 2
# 8
# 2001 PHO
# 2
# 8
# 2001 PHO
# 2
# 8
# 2001 PHO
# 2
# 8
# 2001 PHO
# 1
# 2
# 8
# 2001 PHI
# 2
# 8
# 2001 PHI
# 2
# 8
# 2001 PHI
# 2
# 8
# 2001 PHI
# 2
# 8
# 2001 PHI
# 1
# 2
# 8
# 2001 ORL
# 2
# 8
# 2001 ORL
# 2
# 8
# 2001 ORL
# 2
# 8
# 2001 ORL
# 2
# 8
# 2001 ORL
# 1
# 2
# 3
# 2001 OKC
# 2
# 3
# 2001 OKC
# 2
# 3
# 2001 OKC
# 2
# 3
# 2001 OKC
# 2
# 3
# 2001 OKC
# 1
# 2
# 8
# 2001 NYK
# 2
# 8
# 2001 NYK
# 2
# 8
# 2001 NYK
# 2
# 8
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2001 NYK
# 2
# 8
# 2001 NYK
# 1
# 2
# 4.2
# 2001 NOH
# 2
# 4.2
# 2001 NOH
# 2
# 4.2
# 2001 NOH
# 2
# 4.2
# 2001 NOH
# 2
# 4.2
# 2001 NOH
# 1
# 2
# 8
# 2001 MIN
# 2
# 8
# 2001 MIN
# 2
# 8
# 2001 MIN
# 2
# 8
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 MIN
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2001 MIN
# 1
# 2
# 8
# 2001 MIL
# 2
# 8
# 2001 MIL
# 2
# 8
# 2001 MIL
# 2
# 8
# 2001 MIL
# 2
# 8
# 2001 MIL
# 1
# 2
# 8
# 2001 MIA
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2001 MIA
# 2
# 8
# 2001 MIA
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 MIA
# 2
# 8
# 2001 MIA
# 1
# 2
# 5
# 2001 MEM
# 2
# 5
# 2001 MEM
# 2
# 5
# 2001 MEM
# 2
# 5
# 2001 MEM
# 2
# 5
# 2001 MEM
# 1
# 2
# 8
# 2001 LAL
# 2
# 8
# 2001 LAL
# 2
# 8
# 2001 LAL
# 2
# 8
# 2001 LAL
# 2
# 8
# 2001 LAL
# 1
# 2
# 8
# 2001 LAC
# 2
# 8
# 2001 LAC
# 2
# 8
# 2001 LAC
# 2
# 8
# 2001 LAC
# 2
# 8
# 2001 LAC
# 1
# 2
# 8
# 2001 IND
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2001 IND
# 2
# 8
# 2001 IND
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 IND
# 2
# 8
# 2001 IND
# 1
# 2
# 8
# 2001 HOU
# 2
# 8
# 2001 HOU
# 2
# 8
# 2001 HOU
# 2
# 8
# 2001 HOU
# 2
# 8
# 2001 HOU
# 1
# 2
# 8
# 2001 GSW
# 2
# 8
# 2001 GSW
# 2
# 8
# 2001 GSW
# 2
# 8
# 2001 GSW
# 2
# 8
# 2001 GSW
# 1
# 2
# 8
# 2001 DET
# 2
# 8
# 2001 DET
# 2
# 8
# 2001 DET
# 2
# 8
# 2001 DET
# 2
# 8
# 2001 DET
# 1
# 2
# 8
# 2001 DEN
# 2
# 8
# 2001 DEN
# 2
# 8
# 2001 DEN
# 2
# 8
# 2001 DEN
# 2
# 8
# 2001 DEN
# 1
# 2
# 8
# 2001 DAL
# 2
# 8
# 2001 DAL
# 2
# 8
# 2001 DAL
# 2
# 8
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2001 DAL
# 2
# 8
# 2001 DAL
# 1
# 2
# 8
# 2001 CLE
# 2
# 8
# 2001 CLE
# 2
# 8
# 2001 CLE
# 2
# 8
# 2001 CLE
# 2
# 8
# 2001 CLE
# 1
# 2
# 8
# 2001 CHI
# 2
# 8
# 2001 CHI
# 2
# 8
# 2001 CHI
# 2
# 8
# 2001 CHI
# 2
# 8
# 2001 CHI
# 1
# 2
# 6.2
# 2001 CHA
# 2
# 6.2
# 2001 CHA
# 2
# 6.2
# 2001 CHA
# 2
# 6.2
# 2001 CHA
# 2
# 6.2
# 2001 CHA
# 1
# 2
# 8
# 2001 NJN
# 2
# 8
# 2001 NJN
# 2
# 8
# 2001 NJN
# 2
# 8
# 2001 NJN
# 2
# 8
# 2001 NJN
# 1
# 2
# 8
# 2002 ATL
# 2
# 8
# 2002 ATL
# 2
# 8
# 2002 ATL
# 2
# 8
# 2002 ATL
# 2
# 8
# 2002 ATL
# 1
# 2
# 8
# 2002 BOS
# 2
# 8
# 2002 BOS
# 2
# 8
# 2002 BOS
# 2
# 8
# 2002 BOS
# 2
# 8
# 2002 BOS
# 1
# 2
# 8
# 2002 WAS
# 2
# 8
# 2002 WAS
# 2
# 8
# 2002 WAS
# 2
# 8
# 2002 WAS
# 2
# 8
# 2002 WAS
# 1
# 2
# 8
# 2002 UTA
# 2
# 8
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 1 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2002 UTA
# 2
# 8
# 2002 UTA
# 2
# 8
# 2002 UTA
# 2
# 8
# 2002 UTA
# 1
# 2
# 8
# 2002 TOR
# 2
# 8
# 2002 TOR
# 2
# 8
# 2002 TOR
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 TOR
# 2
# 8
# 2002 TOR
# 1
# 2
# 8
# 2002 SAS
# 2
# 8
# 2002 SAS
# 2
# 8
# 2002 SAS
# 2
# 8
# 2002 SAS
# 2
# 8
# 2002 SAS
# 1
# 2
# 8
# 2002 SAC
# 2
# 8
# 2002 SAC
# 2
# 8
# 2002 SAC
# 2
# 8
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2002 SAC
# 2
# 8
# 2002 SAC
# 1
# 2
# 8
# 2002 POR
# 2
# 8
# 2002 POR
# 2
# 8
# 2002 POR
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 POR
# 2
# 8
# 2002 POR
# 1
# 2
# 8
# 2002 PHO
# 2
# 8
# 2002 PHO
# 2
# 8
# 2002 PHO
# 2
# 8
# 2002 PHO
# 2
# 8
# 2002 PHO
# 1
# 2
# 8
# 2002 PHI
# 2
# 8
# 2002 PHI
# 2
# 8
# 2002 PHI
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 PHI
# 2
# 8
# 2002 PHI
# 1
# 2
# 8
# 2002 ORL
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2002 ORL
# 2
# 8
# 2002 ORL
# 2
# 8
# 2002 ORL
# 2
# 8
# 2002 ORL
# 1
# 2
# 3
# 2002 OKC
# 2
# 3
# 2002 OKC
# 2
# 3
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2002 OKC
# 2
# 3
# 2002 OKC
# 2
# 3
# 2002 OKC
# 1
# 2
# 8
# 2002 NYK
# 2
# 8
# 2002 NYK
# 2
# 8
# 2002 NYK
# 2
# 8
# 2002 NYK
# 2
# 8
# 2002 NYK
# 1
# 2
# 4.2
# 2002 NOH
# 2
# 4.2
# 2002 NOH
# 2
# 4.2
# 2002 NOH
# 2
# 4.2
# 2002 NOH
# 2
# 4.2
# 2002 NOH
# 1
# 2
# 8
# 2002 MIN
# 2
# 8
# 2002 MIN
# 2
# 8
# 2002 MIN
# 2
# 8
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 MIN
# 2
# 8
# 2002 MIN
# 1
# 2
# 8
# 2002 MIL
# 2
# 8
# 2002 MIL
# 2
# 8
# 2002 MIL
# 2
# 8
# 2002 MIL
# 2
# 8
# 2002 MIL
# 1
# 2
# 8
# 2002 MIA
# 2
# 8
# 2002 MIA
# 2
# 8
# 2002 MIA
# 2
# 8
# 2002 MIA
# 2
# 8
# 2002 MIA
# 1
# 2
# 8
# 2002 MEM
# 2
# 8
# 2002 MEM
# 2
# 8
# 2002 MEM
# 2
# 8
# 2002 MEM
# 2
# 8
# 2002 MEM
# 1
# 2
# 8
# 2002 LAL
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2002 LAL
# 2
# 8
# 2002 LAL
# 2
# 8
# 2002 LAL
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2002 LAL
# 1
# 2
# 8
# 2002 LAC
# 2
# 8
# 2002 LAC
# 2
# 8
# 2002 LAC
# 2
# 8
# 2002 LAC
# 2
# 8
# 2002 LAC
# 1
# 2
# 8
# 2002 IND
# 2
# 8
# 2002 IND
# 2
# 8
# 2002 IND
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 IND
# 2
# 8
# 2002 IND
# 1
# 2
# 8
# 2002 HOU
# 2
# 8
# 2002 HOU
# 2
# 8
# 2002 HOU
# 2
# 8
# 2002 HOU
# 2
# 8
# 2002 HOU
# 1
# 2
# 8
# 2002 GSW
# 2
# 8
# 2002 GSW
# 2
# 8
# 2002 GSW
# 2
# 8
# 2002 GSW
# 2
# 8
# 2002 GSW
# 1
# 2
# 8
# 2002 DET
# 2
# 8
# 2002 DET
# 2
# 8
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2002 DET
# 2
# 8
# 2002 DET
# 2
# 8
# 2002 DET
# 1
# 2
# 8
# 2002 DEN
# 2
# 8
# 2002 DEN
# 2
# 8
# 2002 DEN
# 2
# 8
# 2002 DEN
# 2
# 8
# 2002 DEN
# 1
# 2
# 8
# 2002 DAL
# 2
# 8
# 2002 DAL
# 2
# 8
# 2002 DAL
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 DAL
# 2
# 8
# 2002 DAL
# 1
# 2
# 8
# 2002 CLE
# 2
# 8
# 2002 CLE
# 2
# 8
# 2002 CLE
# 2
# 8
# 2002 CLE
# 2
# 8
# 2002 CLE
# 1
# 2
# 8
# 2002 CHI
# 2
# 8
# 2002 CHI
# 2
# 8
# 2002 CHI
# 2
# 8
# 2002 CHI
# 2
# 8
# 2002 CHI
# 1
# 2
# 6.2
# 2002 CHA
# 2
# 6.2
# 2002 CHA
# 2
# 6.2
# 2002 CHA
# 2
# 6.2
# 2002 CHA
# 2
# 6.2
# 2002 CHA
# 1
# 2
# 8
# 2002 NJN
# 2
# 8
# 2002 NJN
# 2
# 8
# 2002 NJN
# 2
# 8
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 1 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2002 NJN
# 2
# 8
# 2002 NJN
# 1
# 2
# 8
# 2003 ATL
# 2
# 8
# 2003 ATL
# 2
# 8
# 2003 ATL
# 2
# 8
# 2003 ATL
# 2
# 8
# 2003 ATL
# 1
# 2
# 8
# 2003 BOS
# 2
# 8
# 2003 BOS
# 2
# 8
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2003 BOS
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 BOS
# 2
# 8
# 2003 BOS
# 1
# 2
# 8
# 2003 WAS
# 2
# 8
# 2003 WAS
# 2
# 8
# 2003 WAS
# 2
# 8
# 2003 WAS
# 2
# 8
# 2003 WAS
# 1
# 2
# 8
# 2003 UTA
# 2
# 8
# 2003 UTA
# 2
# 8
# 2003 UTA
# 2
# 8
# 2003 UTA
# 2
# 8
# 2003 UTA
# 1
# 2
# 8
# 2003 TOR
# 2
# 8
# 2003 TOR
# 2
# 8
# 2003 TOR
# 2
# 8
# 2003 TOR
# 2
# 8
# 2003 TOR
# 1
# 2
# 8
# 2003 SAS
# 2
# 8
# 2003 SAS
# 2
# 8
# 2003 SAS
# 2
# 8
# 2003 SAS
# 2
# 8
# 2003 SAS
# 1
# 2
# 8
# 2003 SAC
# 2
# 8
# 2003 SAC
# 2
# 8
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2 Fail power-forward shooting-guard
# 2 Success point-guard shooting-guard
# 2003 SAC
# 2
# 8
# 2003 SAC
# 2
# 8
# 2003 SAC
# 1
# 2
# 8
# 2003 POR
# 2
# 8
# 2003 POR
# 2
# 8
# 2003 POR
# 2
# 8
# 2003 POR
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2003 POR
# 1
# 2
# 8
# 2003 PHO
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2003 PHO
# 2
# 8
# 2003 PHO
# 2
# 8
# 2003 PHO
# 2
# 8
# 2003 PHO
# 1
# 2
# 8
# 2003 PHI
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2003 PHI
# 2
# 8
# 2003 PHI
# 2
# 8
# 2003 PHI
# 2
# 8
# 2003 PHI
# 1
# 2
# 8
# 2003 ORL
# 2
# 8
# 2003 ORL
# 2
# 8
# 2003 ORL
# 2
# 8
# 2003 ORL
# 2
# 8
# 2003 ORL
# 1
# 2
# 3
# 2003 OKC
# 2
# 3
# 2003 OKC
# 2
# 3
# 2003 OKC
# 2
# 3
# 2003 OKC
# 2
# 3
# 2003 OKC
# 1
# 2
# 8
# 2003 NYK
# 2
# 8
# 2003 NYK
# 2
# 8
# 2003 NYK
# 2
# 8
# 2003 NYK
# 2
# 8
# 2003 NYK
# 1
# 2
# 8
# 2003 NOH
# 2
# 8
# 2003 NOH
# 2
# 8
# 2003 NOH
# 2
# 8
# 2003 NOH
# 2
# 8
# 2003 NOH
# 1
# 2
# 8
# 2003 MIN
# 2
# 8
# 2003 MIN
# 2
# 8
# 2003 MIN
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 MIN
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2003 MIN
# 1
# 2
# 8
# 2003 MIL
# 2
# 8
# 2003 MIL
# 2
# 8
# 2003 MIL
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 MIL
# 2
# 8
# 2003 MIL
# 1
# 2
# 8
# 2003 MIA
# 2
# 8
# 2003 MIA
# 2
# 8
# 2003 MIA
# 2
# 8
# 2003 MIA
# 2
# 8
# 2003 MIA
# 1
# 2
# 8
# 2003 MEM
# 2
# 8
# 2003 MEM
# 2
# 8
# 2003 MEM
# 2
# 8
# 2003 MEM
# 2
# 8
# 2003 MEM
# 1
# 2
# 8
# 2003 LAL
# 2
# 8
# 2003 LAL
# 2
# 8
# 2003 LAL
# 2
# 8
# 2003 LAL
# 2
# 8
# 2003 LAL
# 1
# 2
# 8
# 2003 LAC
# 2
# 8
# 2003 LAC
# 2
# 8
# 2003 LAC
# 2
# 8
# 2003 LAC
# 2
# 8
# 2003 LAC
# 1
# 2
# 8
# 2003 IND
# 2
# 8
# 2003 IND
# 2
# 8
# 2003 IND
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 IND
# 2
# 8
# 2003 IND
# 1
# 2
# 8
# 2003 HOU
# 2
# 8
# 2003 HOU
# 2
# 8
# 2003 HOU
# 2
# 8
# 2003 HOU
# 2
# 8
# 2003 HOU
# 1
# 2
# 8
# 2003 GSW
# 2
# 8
# 2003 GSW
# 2
# 8
# 2003 GSW
# 2
# 8
# 2003 GSW
# 2
# 8
# 2003 GSW
# 1
# 2
# 8
# 2003 DET
# 2
# 8
# 2003 DET
# 2
# 8
# 2003 DET
# 2
# 8
# 2003 DET
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2003 DET
# 1
# 2
# 8
# 2003 DEN
# 2
# 8
# 2003 DEN
# 2
# 8
# 2003 DEN
# 2
# 8
# 2003 DEN
# 2
# 8
# 2003 DEN
# 1
# 2
# 8
# 2003 DAL
# 2
# 8
# 2003 DAL
# 2
# 8
# 2003 DAL
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 DAL
# 2
# 8
# 2003 DAL
# 1
# 2
# 8
# 2003 CLE
# 2
# 8
# 2003 CLE
# 2
# 8
# 2003 CLE
# 2
# 8
# 2003 CLE
# 2
# 8
# 2003 CLE
# 1
# 2
# 8
# 2003 CHI
# 2
# 8
# 2003 CHI
# 2
# 8
# 2003 CHI
# 2
# 8
# 2003 CHI
# 2
# 8
# 2003 CHI
# 1
# 2
# 2003 CHA
# 2
# 2003 CHA
# 2
# 2003 CHA
# 2
# 2003 CHA
# 2
# 2003 CHA
# 1
# 2
# 8
# 2003 NJN
# 2
# 8
# 2003 NJN
# 2
# 8
# 2003 NJN
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2003 NJN
# 2
# 8
# 2003 NJN
# 1
# 2
# 8
# 2004 ATL
# 2
# 8
# 2004 ATL
# 2
# 8
# 2004 ATL
# 2
# 8
# 2004 ATL
# 2
# 8
# 2004 ATL
# 1
# 2
# 8
# 2004 BOS
# 2
# 8
# 2004 BOS
# 2
# 8
# 2004 BOS
# 2
# 8
# 2004 BOS
# 2
# 8
# 2004 BOS
# 1
# 2
# 8
# 2004 WAS
# 2
# 8
# 2004 WAS
# 2
# 8
# 2004 WAS
# 2
# 8
# 2004 WAS
# 2
# 8
# 2004 WAS
# 1
# 2
# 8
# 2004 UTA
# 2
# 8
# 2004 UTA
# 2
# 8
# 2004 UTA
# 2
# 8
# 2004 UTA
# 2
# 8
# 2004 UTA
# 1
# 2
# 8
# 2004 TOR
# 2
# 8
# 2004 TOR
# 2
# 8
# 2004 TOR
# 2
# 8
# 2004 TOR
# 2
# 8
# 2004 TOR
# 1
# 2
# 8
# 2004 SAS
# 2
# 8
# 2004 SAS
# 2
# 8
# 2004 SAS
# 2
# 8
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2 Fail power-forward small-forward
# 2 Success point-guard small-forward
# 2004 SAS
# 2
# 8
# 2004 SAS
# 1
# 2
# 8
# 2004 SAC
# 2
# 8
# 2004 SAC
# 2
# 8
# 2004 SAC
# 2
# 8
# 2004 SAC
# 2
# 8
# 2004 SAC
# 1
# 2
# 8
# 2004 POR
# 2
# 8
# 2004 POR
# 2
# 8
# 2004 POR
# 2
# 8
# 2004 POR
# 2
# 8
# 2004 POR
# 1
# 2
# 8
# 2004 PHO
# 2
# 8
# 2004 PHO
# 2
# 8
# 2004 PHO
# 2
# 8
# 2004 PHO
# 2
# 8
# 2004 PHO
# 1
# 2
# 8
# 2004 PHI
# 2
# 8
# 2004 PHI
# 2
# 8
# 2004 PHI
# 2
# 8
# 2004 PHI
# 2
# 8
# 2004 PHI
# 1
# 2
# 8
# 2004 ORL
# 2
# 8
# 2004 ORL
# 2
# 8
# 2004 ORL
# 2
# 8
# 2004 ORL
# 2
# 8
# 2004 ORL
# 1
# 2
# 3
# 2004 OKC
# 2
# 3
# 2004 OKC
# 2
# 3
# 2004 OKC
# 2
# 3
# 2004 OKC
# 2
# 3
# 2004 OKC
# 1
# 2
# 8
# 2004 NYK
# 2
# 8
# 2004 NYK
# 2
# 8
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2004 NYK
# 2
# 8
# 2004 NYK
# 2
# 8
# 2004 NYK
# 1
# 2
# 8
# 2004 NOH
# 2
# 8
# 2004 NOH
# 2
# 8
# 2004 NOH
# 2
# 8
# 2004 NOH
# 2
# 8
# 2004 NOH
# 1
# 2
# 8
# 2004 MIN
# 2
# 8
# 2004 MIN
# 2
# 8
# 2004 MIN
# 2
# 8
# 2004 MIN
# 2
# 8
# 2004 MIN
# 1
# 2
# 8
# 2004 MIL
# 2
# 8
# 2004 MIL
# 2
# 8
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2004 MIL
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2004 MIL
# 2
# 8
# 2004 MIL
# 1
# 2
# 8
# 2004 MIA
# 2
# 8
# 2004 MIA
# 2
# 8
# 2004 MIA
# 2
# 8
# 2004 MIA
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2004 MIA
# 1
# 2
# 8
# 2004 MEM
# 2
# 8
# 2004 MEM
# 2
# 8
# 2004 MEM
# 2
# 8
# 2004 MEM
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2004 MEM
# 1
# 2
# 8
# 2004 LAL
# 2
# 8
# 2004 LAL
# 2
# 8
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2 Success power-forward shooting-guard
# 2004 LAL
# 2
# 8
# 2004 LAL
# 2
# 8
# 2004 LAL
# 1
# 2
# 8
# 2004 LAC
# 2
# 8
# 2004 LAC
# 2
# 8
# 2004 LAC
# 2
# 8
# 2004 LAC
# 2
# 8
# 2004 LAC
# 1
# 2
# 8
# 2004 IND
# 2
# 8
# 2004 IND
# 2
# 8
# 2004 IND
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2004 IND
# 2
# 8
# 2004 IND
# 1
# 2
# 8
# 2004 HOU
# 2
# 8
# 2004 HOU
# 2
# 8
# 2004 HOU
# 2
# 8
# 2004 HOU
# 2
# 8
# 2004 HOU
# 1
# 2
# 8
# 2004 GSW
# 2
# 8
# 2004 GSW
# 2
# 8
# 2004 GSW
# 2
# 8
# 2004 GSW
# 2
# 8
# 2004 GSW
# 1
# 2
# 8
# 2004 DET
# 2
# 8
# 2004 DET
# 2
# 8
# 2004 DET
# 2
# 8
# 2004 DET
# 2
# 8
# 2004 DET
# 1
# 2
# 8
# 2004 DEN
# 2
# 8
# 2004 DEN
# 2
# 8
# 2004 DEN
# 2
# 8
# 2004 DEN
# 2
# 8
# 2004 DEN
# 1
# 2
# 8
# 2004 DAL
# 2
# 8
# 2004 DAL
# 2
# 8
# 2004 DAL
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2004 DAL
# 2
# 8
# 2004 DAL
# 1
# 2
# 8
# 2004 CLE
# 2
# 8
# 2004 CLE
# 2
# 8
# 2004 CLE
# 2
# 8
# 2004 CLE
# 2
# 8
# 2004 CLE
# 1
# 2
# 8
# 2004 CHI
# 2
# 8
# 2004 CHI
# 2
# 8
# 2004 CHI
# 2
# 8
# 2004 CHI
# 2
# 8
# 2004 CHI
# 1
# 2
# 2004 CHA
# 2
# 2004 CHA
# 2
# 2004 CHA
# 2
# 2004 CHA
# 2
# 2004 CHA
# 1
# 2
# 8
# 2004 NJN
# 2
# 8
# 2004 NJN
# 2
# 8
# 2004 NJN
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2004 NJN
# 2
# 8
# 2004 NJN
# 1
# 2
# 8
# 2005 ATL
# 2
# 8
# ...
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2021 ATL
# 1
# 2
# 8
# 2021 BOS
# 2
# 8
# 2021 BOS
# 2
# 8
# 2021 BOS
# 2
# 8
# 2021 BOS
# 2
# 8
# 2021 BOS
# 1
# 2
# 8
# 2021 WAS
# 2
# 8
# 2021 WAS
# 2
# 8
# 2021 WAS
# 2
# 8
# 2021 WAS
# 2
# 8
# 2021 WAS
# 1
# 2
# 8
# 2021 UTA
# 2
# 8
# 2021 UTA
# 2
# 8
# 2021 UTA
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2021 UTA
# 2
# 8
# 2021 UTA
# 1
# 2
# 8
# 2021 TOR
# 2
# 8
# 2021 TOR
# 2
# 8
# 2021 TOR
# 2
# 8
# 2021 TOR
# 2
# 8
# 2021 TOR
# 1
# 2
# 8
# 2021 SAS
# 2
# 8
# 2021 SAS
# 2
# 8
# 2021 SAS
# 2
# 8
# 2021 SAS
# 2
# 8
# 2021 SAS
# 1
# 2
# 8
# 2021 SAC
# 2
# 8
# 2021 SAC
# 2
# 8
# 2021 SAC
# 2
# 8
# 2021 SAC
# 2
# 8
# 2021 SAC
# 1
# 2
# 8
# 2021 POR
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2021 POR
# 2
# 8
# 2021 POR
# 2
# 8
# 2021 POR
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2021 POR
# 1
# 2
# 8
# 2021 PHO
# 2
# 8
# 2021 PHO
# 2
# 8
# 2021 PHO
# 2
# 8
# 2021 PHO
# 2
# 8
# 2021 PHO
# 1
# 2
# 8
# 2021 PHI
# 2
# 8
# 2021 PHI
# 2
# 8
# 2021 PHI
# 2
# 8
# 2021 PHI
# 2
# 8
# 2021 PHI
# 1
# 2
# 8
# 2021 ORL
# 2
# 8
# 2021 ORL
# 2
# 8
# 2021 ORL
# 2
# 8
# 2021 ORL
# 2
# 8
# 2021 ORL
# 1
# 2
# 8
# 2021 OKC
# 2
# 8
# 2021 OKC
# 2
# 8
# 2021 OKC
# 2
# 8
# 2021 OKC
# 2
# 8
# 2021 OKC
# 1
# 2
# 8
# 2021 NYK
# 2
# 8
# 2021 NYK
# 2
# 8
# 2021 NYK
# 2
# 8
# 2021 NYK
# 2
# 8
# 2021 NYK
# 1
# 2
# 4.2
# 2021 NOH
# 2
# 4.2
# 2021 NOH
# 2
# 4.2
# 2021 NOH
# 2
# 4.2
# 2021 NOH
# 2
# 4.2
# 2021 NOH
# 1
# 2
# 8
# 2021 MIN
# 2
# 8
# 2021 MIN
# 2
# 8
# 2021 MIN
# 2
# 8
# 2021 MIN
# 2
# 8
# 2021 MIN
# 1
# 2
# 8
# 2021 MIL
# 2
# 8
# 2021 MIL
# 2
# 8
# 2021 MIL
# 2
# 8
# 2021 MIL
# 2
# 8
# 2021 MIL
# 1
# 2
# 8
# 2021 MIA
# 2
# 8
# 2021 MIA
# 2
# 8
# 2021 MIA
# 2
# 8
# 2021 MIA
# 2
# 8
# 2021 MIA
# 1
# 2
# 8
# 2021 MEM
# 2
# 8
# 2021 MEM
# 2
# 8
# 2021 MEM
# 2
# 8
# 2021 MEM
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2021 MEM
# 1
# 2
# 8
# 2021 LAL
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2021 LAL
# 2
# 8
# 2021 LAL
# 2
# 8
# 2021 LAL
# 2
# 8
# 2021 LAL
# 1
# 2
# 8
# 2021 LAC
# 2
# 8
# 2021 LAC
# 2
# 8
# 2021 LAC
# 2
# 8
# 2021 LAC
# 2
# 8
# 2021 LAC
# 1
# 2
# 8
# 2021 IND
# 2
# 8
# 2021 IND
# 2
# 8
# 2021 IND
# 2
# 8
# 2021 IND
# 2
# 8
# 2021 IND
# 1
# 2
# 8
# 2021 HOU
# 2
# 8
# 2021 HOU
# 2
# 8
# 2021 HOU
# 2
# 8
# 2021 HOU
# 2
# 8
# 2021 HOU
# 1
# 2
# 8
# 2021 GSW
# 2
# 8
# 2021 GSW
# 2
# 8
# 2021 GSW
# 2
# 8
# 2021 GSW
# 2
# 8
# 2021 GSW
# 1
# 2
# 8
# 2021 DET
# 2
# 8
# 2021 DET
# 2
# 8
# 2021 DET
# 2
# 8
# 2021 DET
# 2
# 8
# 2021 DET
# 1
# 2
# 8
# 2021 DEN
# 2
# 8
# 2021 DEN
# 2
# 8
# 2021 DEN
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2021 DEN
# 2
# 8
# 2021 DEN
# 1
# 2
# 8
# 2021 DAL
# 2
# 8
# 2021 DAL
# 2
# 8
# 2021 DAL
# 2
# 8
# 2021 DAL
# 2
# 8
# 2021 DAL
# 1
# 2
# 8
# 2021 CLE
# 2
# 8
# 2021 CLE
# 2
# 8
# 2021 CLE
# 2
# 8
# 2021 CLE
# 2
# 8
# 2021 CLE
# 1
# 2
# 8
# 2021 CHI
# 2
# 8
# 2021 CHI
# 2
# 8
# 2021 CHI
# 2
# 8
# 2021 CHI
# 2
# 8
# 2021 CHI
# 1
# 2
# 6.1
# 2021 CHA
# 2
# 6.1
# 2021 CHA
# 2
# 6.1
# 2021 CHA
# 2
# 6.1
# 2021 CHA
# 2
# 6.1
# 2021 CHA
# 1
# 2
# 7
# 2021 NJN
# 2
# 7
# 2021 NJN
# 2
# 7
# 2021 NJN
# 2
# 7
# 2021 NJN
# 2
# 7
# 2021 NJN
# 1
# 2
# 8
# 2022 ATL
# 2
# 8
# 2022 ATL
# 2
# 8
# 2022 ATL
# 2
# 8
# 2022 ATL
# 2
# 8
# 2022 ATL
# 1
# 2
# 8
# 2022 BOS
# 2
# 8
# 2022 BOS
# 2
# 8
# 2022 BOS
# 2
# 8
# 2022 BOS
# 2
# 8
# 2022 BOS
# 1
# 2
# 8
# 2022 WAS
# 2
# 8
# 2022 WAS
# 2
# 8
# 2022 WAS
# 2
# 8
# 2022 WAS
# 2
# 8
# 2022 WAS
# 1
# 2
# 8
# 2022 UTA
# 2
# 8
# 2022 UTA
# 2
# 8
# 2022 UTA
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2022 UTA
# 2
# 8
# 2022 UTA
# 1
# 2
# 8
# 2022 TOR
# 2
# 8
# 2022 TOR
# 2
# 8
# 2022 TOR
# 2
# 8
# 2022 TOR
# 2
# 8
# 2022 TOR
# 1
# 2
# 8
# 2022 SAS
# 2
# 8
# 2022 SAS
# 2
# 8
# 2022 SAS
# 2
# 8
# 2022 SAS
# 2
# 8
# 2022 SAS
# 1
# 2
# 8
# 2022 SAC
# 2
# 8
# 2022 SAC
# 2
# 8
# 2022 SAC
# 2
# 8
# 2022 SAC
# 2
# 8
# 2022 SAC
# 1
# 2
# 8
# 2022 POR
# 2
# 8
# 2022 POR
# 2
# 8
# 2022 POR
# 2
# 8
# 2022 POR
# 2
# 8
# 2022 POR
# 1
# 2
# 8
# 2022 PHO
# 2
# 8
# 2022 PHO
# 2
# 8
# 2022 PHO
# 2
# 8
# 2022 PHO
# 2
# 8
# 2022 PHO
# 1
# 2
# 8
# 2022 PHI
# 2
# 8
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2 Fail power-forward point-guard
# 2 Fail point-guard point-guard
# 2 Success shooting-guard point-guard
# 2022 PHI
# 2
# 8
# 2022 PHI
# 2
# 8
# 2022 PHI
# 2
# 8
# 2022 PHI
# 1
# 2
# 8
# 2022 ORL
# 2
# 8
# 2022 ORL
# 2
# 8
# 2022 ORL
# 2
# 8
# 2022 ORL
# 2
# 8
# 2022 ORL
# 1
# 2
# 8
# 2022 OKC
# 2
# 8
# 2022 OKC
# 2
# 8
# 2022 OKC
# 2
# 8
# 2022 OKC
# 2
# 8
# 2022 OKC
# 1
# 2
# 8
# 2022 NYK
# 2
# 8
# 2022 NYK
# 2
# 8
# 2022 NYK
# 2
# 8
# 2022 NYK
# 2
# 8
# 2022 NYK
# 1
# 2
# 4.2
# 2022 NOH
# 2
# 4.2
# 2022 NOH
# 2
# 4.2
# 2022 NOH
# 2
# 4.2
# 2022 NOH
# 2
# 4.2
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2 Fail power-forward center
# 2 Fail point-guard center
# 2 Success shooting-guard center
# 2022 NOH
# 1
# 2
# 8
# 2022 MIN
# 2
# 8
# 2022 MIN
# 2
# 8
# 2022 MIN
# 2
# 8
# 2022 MIN
# 2
# 8
# 2022 MIN
# 1
# 2
# 8
# 2022 MIL
# 2
# 8
# 2022 MIL
# 2
# 8
# 2022 MIL
# 2
# 8
# 2022 MIL
# 2
# 8
# 2022 MIL
# 1
# 2
# 8
# 2022 MIA
# 2
# 8
# 2022 MIA
# 2
# 8
# 2022 MIA
# 2
# 8
# 2022 MIA
# 2
# 8
# 2022 MIA
# 1
# 2
# 8
# 2022 MEM
# 2
# 8
# 2022 MEM
# 2
# 8
# 2022 MEM
# 2
# 8
# 2022 MEM
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2022 MEM
# 1
# 2
# 8
# 2022 LAL
# 2
# 8
# 2022 LAL
# 2
# 8
# 2022 LAL
# 2
# 8
# 2022 LAL
# 2
# 8
# 2022 LAL
# 1
# 2
# 8
# 2022 LAC
# 2
# 8
# 2022 LAC
# 2
# 8
# 2022 LAC
# 2
# 8
# 2022 LAC
# 2
# 8
# 2022 LAC
# 1
# 2
# 8
# 2022 IND
# 2
# 8
# 2022 IND
# 2
# 8
# 2022 IND
# 2
# 8
# 2022 IND
# 2
# 8
# 2022 IND
# 1
# 2
# 8
# 2022 HOU
# 2
# 8
# 2022 HOU
# 2
# 8
# 2022 HOU
# 2
# 8
# 2022 HOU
# 2
# 8
# 2022 HOU
# 1
# 2
# 8
# 2022 GSW
# 2
# 8
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2 Success power-forward point-guard
# 2022 GSW
# 2
# 8
# 2022 GSW
# 2
# 8
# 2022 GSW
# 2
# 8
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2 Success power-forward center
# 2022 GSW
# 1
# 2
# 8
# 2022 DET
# 2
# 8
# 2022 DET
# 2
# 8
# 2022 DET
# 2
# 8
# 2022 DET
# 2
# 8
# 2022 DET
# 1
# 2
# 8
# 2022 DEN
# 2
# 8
# 2022 DEN
# 2
# 8
# 2022 DEN
# 2
# 8
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2 Success power-forward small-forward
# 2022 DEN
# 2
# 8
# 2022 DEN
# 1
# 2
# 8
# 2022 DAL
# 2
# 8
# 2022 DAL
# 2
# 8
# 2022 DAL
# 2
# 8
# 2022 DAL
# 2
# 8
# 2022 DAL
# 1
# 2
# 8
# 2022 CLE
# 2
# 8
# 2022 CLE
# 2
# 8
# 2022 CLE
# 2
# 8
# 2022 CLE
# 2
# 8
# 2022 CLE
# 1
# 2
# 8
# 2022 CHI
# 2
# 8
# 2022 CHI
# 2
# 8
# 2022 CHI
# 2
# 8
# 2022 CHI
# 2
# 8
# 2022 CHI
# 1
# 2
# 6.1
# 2022 CHA
# 2
# 6.1
# 2022 CHA
# 2
# 6.1
# 2022 CHA
# 2
# 6.1
# 2022 CHA
# 2
# 6.1
# 2022 CHA
# 1
# 2
# 7
# 2022 NJN
# 2
# 7
# 2022 NJN
# 2
# 7
# 2022 NJN
# 2
# 7
# 2022 NJN
# 2
# 7
# 2022 NJN

# %%
! ls ../../Data
# Out:
# NBA Win-Loss.xlsx
# win_loss_df.xlsx
# year_position.pickle
# year_team.pickle

# %%
win_loss_df.to_csv("../../Data/win_loss_completed_df.csv", index=False)

# %%
# for x in range(1,3):
#     for position in positions:
#         print(x,position)
#         print(win_loss_df[win_loss_df["team2-"+str(x)+"-"+position] == "Null"]["team2"].unique())

# for x in range(1,3):
#     for position in positions:
#         print(x,position)
#         print(win_loss_df[win_loss_df["team1-"+str(x)+"-"+position] == "Null"]["team1"].unique())

# %%
# win_loss_df[(win_loss_df["team1-2-center"] == "Null")&(win_loss_df["team1"] == "NYK")]

# %%
# win_loss_df[(win_loss_df["team1"] == "CHO")]

# %%
# for year in years:
#     for team in teams:
#         try:
#             if len(year_team[(year,team)]) < 9:
#                 print(year,team)
#         except:
#             pass

# %%
# year_team[("2012","NYK")]

# %%
# win_loss_df[(win_loss_df["team1"] == "SAS") & (win_loss_df["team1-1-power-forward"] == "Null")]

# %%
# win_loss_df[win_loss_df["team2-1-point-guard"] == "Null"]
